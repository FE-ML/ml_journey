# %%
def train_model(model, learning_rate, epochs):
    print(model, learning_rate, epochs)

# %%
train_model(
    model='RandomForest',
    learning_rate=0.01,
    epochs=100
)
# Out:
# RandomForest 0.01 100

# %%
def load_dataset(path='data.csv'):
    pass

load_dataset()

# %%
load_dataset('train.csv')

# %%
import numpy as np
def calculate_mean_metric(*metrics):
    return np.mean(metrics)

# %%
calculate_mean_metric(    
    0.82,
    0.85,
    0.88,
    0.91
)
# Out:
# np.float64(0.865)

# %%
def create_model(**params):
    print(params)

create_model(
    max_depth=10,
    min_samples_split=5,
    random_state=42
)
# Out:
# {'max_depth': 10, 'min_samples_split': 5, 'random_state': 42}

# %%
def log_experiment(name, *numbers, **params):
    print(name, numbers, params)

log_experiment(
    "experiment_1",
    0.91,
    0.87,
    model="xgboost",
    max_depth=8
)
# Out:
# experiment_1 (0.91, 0.87) {'model': 'xgboost', 'max_depth': 8}

# %%
layers = [128, 64, 10]

def build_network(input_size, hidden_size, output_size):
    print(input_size, hidden_size, output_size)

# %%
build_network(*layers)
# Out:
# 128 64 10

# %%
params = {
    "max_depth": 5,
    "random_state": 42
}

# %%
def train(max_depth, random_state):
    print(max_depth, random_state)

# %%
train(**params)
# Out:
# 5 42

# %%
def accuracy(y_true: list[int], y_pred: list[int])->float:
    pass

# %%
def add_metric(metric, metrics=None):
    if metrics is None:
        metrics=[]
    metrics.append(metric)
    return metrics

print(add_metric(0.91))
print(add_metric(0.88))
# Out:
# [0.91]
# [0.88]

# %%
def train(name, /, epochs, *, learning_rate):
    print(name, epochs, learning_rate)
